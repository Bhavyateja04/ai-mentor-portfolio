# %% [markdown]
# <a href="https://colab.research.google.com/github/Bhavyateja04/ai-mentor-portfolio/blob/main/Day1_setup.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q google-genai

# %%
import os, getpass
os.environ['GEMINI_API_KEY'] = getpass.getpass('Paste your Google AI Studio key: ')
# Out:
# Paste your Google AI Studio key: ··········

# %%
from google import genai
client = genai.Client(api_key=os.environ['GEMINI_API_KEY'])

resp = client.models.generate_content(
    model='gemini-2.5-flash',
    contents='Explain the 5-Layer AI Skill Pyramid in 4 short bullet points.'
)
print(resp.text)
# Out:
# The 5-Layer AI Skill Pyramid outlines the progression of expertise from fundamental understanding to cutting-edge innovation:
#
# *   **Base (Foundation):** Start with **Data & AI Literacy**, understanding data principles, AI capabilities, limitations, and ethical considerations.
# *   **Application:** Progress to **AI Tool Proficiency**, effectively using existing AI applications, platforms, and pre-built models for specific tasks.
# *   **Development:** Advance to **AI Engineering**, designing, building, training, and deploying custom AI solutions and models.
# *   **Apex (Leadership):** Reach **AI Strategy & Research**, driving innovation, setting organizational AI vision, and shaping its responsible future.
